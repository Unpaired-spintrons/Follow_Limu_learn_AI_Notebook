# %% [markdown]
# # 模型过拟合与欠拟合

# %% [markdown]
# 通过多项式拟合来探索这些概念

# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

# %% [markdown]
# 对于数据集我们采用多项式进行相关的生成，让模型去找这个多项式

# %% [markdown]
# ![image.png](attachment:image.png)
